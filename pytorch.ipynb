# %% [markdown]
# <a href="https://colab.research.google.com/github/aloysathekge/neural_network/blob/main/pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
x=torch.empty(1)

# %%
print(x)
# Out:
# tensor([502124.])
