# %%
import numpy as np

n = [2, 3, 3, 1]    
W1 = np.random.randn(n[1], n[0])
W2 = np.random.randn(n[2], n[1])
W3 = np.random.randn(n[3], n[2])
b1 = np.random.randn(n[1], 1)
b2 = np.random.randn(n[2], 1)
b3 = np.random.randn(n[3], 1)

# %%
X = np.array([
    [150, 70], # it's our boy Jimmy again! 150 pounds, 70 inches tall. 
    [254, 73],
    [312, 68],
    [120, 60],
    [154, 61],
    [212, 65],
    [216, 67],
    [145, 67],
    [184, 64],
    [130, 69]
])

print(X.shape)
# Out:
# (10, 2)

# %%
A0 = X.T
print(A0.shape) # prints (2, 10)
print(A0)
# Out:
# (2, 10)
# [[150 254 312 120 154 212 216 145 184 130]
#  [ 70  73  68  60  61  65  67  67  64  69]]

# %%
y = np.array([
    0,  # whew, thank God Jimmy isn't at risk for cardiovascular disease.
    1,   # damn, this guy wasn't as lucky
    1, # ok, this guy should have seen it coming. 5"8, 312 lbs isn't great.
    0,
    0,
    1,
    1,
    0,
    1,
    0
])
m = 10

# we need to reshape to a n^[3] x m matrix
Y = y.reshape(n[3], m)
Y.shape
# Out:
# (1, 10)

# %%
def sigmoid(arr):
  return 1 / (1 + np.exp(-1 * arr))

# %%
m = 10

# layer 1 calculations

Z1 = W1 @ A0 + b1  # the @ means matrix multiplication




assert Z1.shape == (n[1], m) # just checking if shapes are good
A1 = sigmoid(Z1)
print("A1 is ", A1)


# layer 2 calculations
Z2 = W2 @ A1 + b2
assert Z2.shape == (n[2], m)
A2 = sigmoid(Z2)

# layer 3 calculations
Z3 = W3 @ A2 + b3
assert Z3.shape == (n[3], m)
A3 = sigmoid(Z3)
# Out:
# A1 is  [[4.07239260e-049 7.08553054e-103 7.25390715e-136 9.97824834e-038
#   2.70714034e-055 3.16487060e-084 1.91585075e-085 8.07082147e-048
#   7.71541954e-070 5.72092994e-039]
#  [2.93389366e-030 1.79457549e-039 5.14876807e-043 2.04148891e-025
#   1.96447914e-028 3.96659911e-034 6.21300363e-035 3.92127688e-029
#   1.33341835e-031 2.19006586e-028]
#  [1.00000000e+000 1.00000000e+000 1.00000000e+000 1.00000000e+000
#   1.00000000e+000 1.00000000e+000 1.00000000e+000 1.00000000e+000
#   1.00000000e+000 1.00000000e+000]]

# %%
print(A3.shape) # prints out (1, 10)
y_hat = A3    
print(y_hat)
# Out:
# (1, 10)
# [[0.73793199 0.73793199 0.73793199 0.73793199 0.73793199 0.73793199
#   0.73793199 0.73793199 0.73793199 0.73793199]]
